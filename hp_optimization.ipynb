# %%
from utils.transformations import ExtendedTransformation, SimpleTransformation
from utils.filters import SimpleFilter
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv("data/preprocessed/train_data.csv")
X_train, y_train = df_train.drop(columns=['Price']), df_train[['Price']]
preprocessor = ExtendedTransformation()
filter = SimpleFilter()
preprocessor.fit(X_train, y_train)
X_processed, y_processed = preprocessor.transform(X_train, y_train)
filter.fit(X_processed, y_processed)
X_filtered, y_filtered = filter.transform(X_processed, y_processed)
# Out:
# X shape:  (20974, 40)
# bin_vars_columns shape:  (36,)
# low_card_columns shape:  37
# X shape:  (20974, 40)
# X_low_card   shape:  (20974, 113)
# X_high_card shape:  (20974, 50)
# X_crossed_features shape:  (20974, 6670)
# X_EXPANDED shape:  (20974, 6835)
# (20974, 6835)
# (20974, 4173)
# (20974, 3193)
# (20974, 1635)
# (20974, 4173)
# (20974, 3193)
# (20974, 1635)

# %%
df_test = pd.read_csv("data/preprocessed/test_data.csv")
X_test, y_test = df_test.drop(columns=['Price']), df_test[['Price']]
X_test_proccesed, y_test_proccessed = preprocessor.transform(X_test, y_test)
X_test_filtered, y_test_filtered = filter.transform(X_test_proccesed, y_test_proccessed)
# Out:
# X shape:  (8989, 40)
# X_low_card   shape:  (8989, 113)
# X_high_card shape:  (8989, 50)
# X_crossed_features shape:  (8989, 6670)
# X_EXPANDED shape:  (8989, 6835)
# (8989, 4173)
# (8989, 3193)
# (8989, 1635)

# %%
import optuna
from sklearn.ensemble import GradientBoostingRegressor, HistGradientBoostingRegressor, RandomForestRegressor
import sklearn.model_selection
def objective(trial):
    x, y = X_filtered, y_filtered.flatten()

    ensemble_model = trial.suggest_categorical("ensemble_model", ["GradientBoost", "RandomForest", "HistGradientBoost"])
    n_estimators = trial.suggest_int("n_estimators", 10, 500, log=True)
    max_depth = trial.suggest_int("max_depth", 5, 32, log=True)
    
    if (ensemble_model == 'GradientBoost'):
        learning_rate = trial.suggest_float("learning_rate", 0.001, 0.1, log=True)
        estimator = GradientBoostingRegressor(n_estimators=n_estimators, max_depth=max_depth, learning_rate=learning_rate)
    elif (ensemble_model == 'HistGradientBoost'):
        learning_rate = trial.suggest_float("learning_rate", 0.001, 0.1, log=True)
        estimator = HistGradientBoostingRegressor(max_iter=n_estimators, max_depth=max_depth, learning_rate=learning_rate)
    else:
        min_split = trial.suggest_int("min_split", 5, 50, log=True)
        estimator = RandomForestRegressor(min_samples_split=min_split, max_depth=max_depth, n_estimators=n_estimators)
    
    scoring = sklearn.model_selection.cross_val_score(estimator, x, y, n_jobs=-1, cv=3, scoring='neg_mean_squared_error')

    return scoring.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
print(study.best_trial)
# Out:
# [I 2025-03-25 08:29:20,316] A new study created in memory with name: no-name-bf79be1a-4e2d-4b96-ae46-fbe93fe4e11f
# [I 2025-03-25 08:30:00,953] Trial 0 finished with value: -0.6136882588682313 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 148, 'max_depth': 12, 'learning_rate': 0.007832458877827188}. Best is trial 0 with value: -0.6136882588682313.
# [I 2025-03-25 08:36:53,331] Trial 1 finished with value: -0.6198213672194938 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 410, 'max_depth': 12, 'learning_rate': 0.08923403782642546}. Best is trial 0 with value: -0.6136882588682313.
# [I 2025-03-25 08:37:32,908] Trial 2 finished with value: -0.6152557218888043 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 154, 'max_depth': 9, 'learning_rate': 0.007467875542970141}. Best is trial 0 with value: -0.6136882588682313.
# [I 2025-03-25 08:37:41,646] Trial 3 finished with value: -0.7697623621522366 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 35, 'max_depth': 5, 'learning_rate': 0.01258818511709921}. Best is trial 0 with value: -0.6136882588682313.
# [I 2025-03-25 08:38:11,343] Trial 4 finished with value: -0.8531982560917218 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 16, 'max_depth': 26, 'learning_rate': 0.010850948635214325}. Best is trial 0 with value: -0.6136882588682313.
# [I 2025-03-25 08:40:04,029] Trial 5 finished with value: -0.577719169041989 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 300, 'max_depth': 6, 'min_split': 21}. Best is trial 5 with value: -0.577719169041989.
# [I 2025-03-25 08:40:13,747] Trial 6 finished with value: -0.6871111402058191 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 34, 'max_depth': 9, 'learning_rate': 0.020349272965086797}. Best is trial 5 with value: -0.577719169041989.
# [I 2025-03-25 08:40:50,646] Trial 7 finished with value: -0.5625944803079851 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 28, 'max_depth': 14, 'learning_rate': 0.06256550071464045}. Best is trial 7 with value: -0.5625944803079851.
# [I 2025-03-25 08:42:14,908] Trial 8 finished with value: -0.5597603490476545 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 187, 'max_depth': 7, 'min_split': 33}. Best is trial 8 with value: -0.5597603490476545.
# [I 2025-03-25 08:49:13,850] Trial 9 finished with value: -0.5207748345271211 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 460, 'max_depth': 26, 'min_split': 32}. Best is trial 9 with value: -0.5207748345271211.
# [I 2025-03-25 08:50:28,562] Trial 10 finished with value: -0.5544765050336949 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 67, 'max_depth': 30, 'min_split': 5}. Best is trial 9 with value: -0.5207748345271211.
# [I 2025-03-25 08:52:05,507] Trial 11 finished with value: -0.553263051862988 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 89, 'max_depth': 29, 'min_split': 5}. Best is trial 9 with value: -0.5207748345271211.
# [I 2025-03-25 08:53:12,855] Trial 12 finished with value: -0.5372045732769871 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 68, 'max_depth': 19, 'min_split': 5}. Best is trial 9 with value: -0.5207748345271211.
# [I 2025-03-25 08:54:15,399] Trial 13 finished with value: -0.5284535921673275 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 66, 'max_depth': 19, 'min_split': 11}. Best is trial 9 with value: -0.5207748345271211.
# [I 2025-03-25 09:01:49,480] Trial 14 finished with value: -0.527025116343193 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 484, 'max_depth': 20, 'min_split': 12}. Best is trial 9 with value: -0.5207748345271211.
# [I 2025-03-25 09:08:49,671] Trial 15 finished with value: -0.5203759411328347 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 499, 'max_depth': 21, 'min_split': 50}. Best is trial 15 with value: -0.5203759411328347.
# [I 2025-03-25 09:12:38,138] Trial 16 finished with value: -0.5201535102657108 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 262, 'max_depth': 22, 'min_split': 50}. Best is trial 16 with value: -0.5201535102657108.
# [I 2025-03-25 09:16:14,202] Trial 17 finished with value: -0.5214876419507432 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 262, 'max_depth': 16, 'min_split': 48}. Best is trial 16 with value: -0.5201535102657108.
# [I 2025-03-25 09:20:09,008] Trial 18 finished with value: -0.5201170821587434 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 266, 'max_depth': 22, 'min_split': 49}. Best is trial 18 with value: -0.5201170821587434.
# [I 2025-03-25 09:22:39,581] Trial 19 finished with value: -0.8767705992686827 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 108, 'max_depth': 15, 'learning_rate': 0.0013230992319148785}. Best is trial 18 with value: -0.5201170821587434.
# [I 2025-03-25 09:26:44,929] Trial 20 finished with value: -0.5203193212248182 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 263, 'max_depth': 23, 'min_split': 29}. Best is trial 18 with value: -0.5201170821587434.
# [I 2025-03-25 09:30:50,275] Trial 21 finished with value: -0.5204308272838789 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 250, 'max_depth': 23, 'min_split': 33}. Best is trial 18 with value: -0.5201170821587434.
# [I 2025-03-25 09:34:19,053] Trial 22 finished with value: -0.5249340278103772 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 211, 'max_depth': 32, 'min_split': 21}. Best is trial 18 with value: -0.5201170821587434.
# [I 2025-03-25 09:39:14,851] Trial 23 finished with value: -0.5193807368931969 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 343, 'max_depth': 17, 'min_split': 39}. Best is trial 23 with value: -0.5193807368931969.
# [I 2025-03-25 09:43:38,700] Trial 24 finished with value: -0.520602106239025 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 318, 'max_depth': 17, 'min_split': 50}. Best is trial 23 with value: -0.5193807368931969.
# [I 2025-03-25 09:45:06,455] Trial 25 finished with value: -0.522683609482384 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 116, 'max_depth': 13, 'min_split': 40}. Best is trial 23 with value: -0.5193807368931969.
# [I 2025-03-25 09:50:30,268] Trial 26 finished with value: -0.5192513883506557 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 369, 'max_depth': 17, 'min_split': 22}. Best is trial 26 with value: -0.5192513883506557.
# [I 2025-03-25 09:54:31,150] Trial 27 finished with value: -0.5253538285041216 and parameters: {'ensemble_model': 'RandomForest', 'n_estimators': 355, 'max_depth': 11, 'min_split': 23}. Best is trial 26 with value: -0.5192513883506557.
# [I 2025-03-25 09:54:47,391] Trial 28 finished with value: -0.9897631712908987 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 10, 'max_depth': 17, 'learning_rate': 0.0010223094932306144}. Best is trial 26 with value: -0.5192513883506557.
# [I 2025-03-25 09:55:27,075] Trial 29 finished with value: -0.7879022845397797 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 154, 'max_depth': 11, 'learning_rate': 0.002384691809937498}. Best is trial 26 with value: -0.5192513883506557.
# [I 2025-03-25 09:56:06,628] Trial 30 finished with value: -0.5181014506636207 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 197, 'max_depth': 26, 'learning_rate': 0.04132458384627081}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 09:56:51,279] Trial 31 finished with value: -0.5208806167661479 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 219, 'max_depth': 26, 'learning_rate': 0.03310261798593977}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 09:57:33,215] Trial 32 finished with value: -0.5187403007003831 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 367, 'max_depth': 18, 'learning_rate': 0.04614430915165204}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 09:58:11,424] Trial 33 finished with value: -0.5190951200202581 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 368, 'max_depth': 14, 'learning_rate': 0.04199663783706904}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 09:58:52,626] Trial 34 finished with value: -0.5182406413001427 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 379, 'max_depth': 13, 'learning_rate': 0.04432096907551843}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 09:59:38,936] Trial 35 finished with value: -0.5196947893217869 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 393, 'max_depth': 9, 'learning_rate': 0.03643537107268872}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 10:00:14,472] Trial 36 finished with value: -0.5203687921166265 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 178, 'max_depth': 12, 'learning_rate': 0.045109504547877696}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 10:00:47,519] Trial 37 finished with value: -0.5367037815590647 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 138, 'max_depth': 10, 'learning_rate': 0.02201928427650288}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 10:01:09,229] Trial 38 finished with value: -0.5199724832593553 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 404, 'max_depth': 14, 'learning_rate': 0.09049828264129647}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 10:01:22,753] Trial 39 finished with value: -0.544603267963054 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 48, 'max_depth': 15, 'learning_rate': 0.05284752356005005}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 10:02:03,352] Trial 40 finished with value: -0.5261477870011322 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 195, 'max_depth': 8, 'learning_rate': 0.023634468258756303}. Best is trial 30 with value: -0.5181014506636207.
# [I 2025-03-25 10:02:41,404] Trial 41 finished with value: -0.5170923246353741 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 326, 'max_depth': 13, 'learning_rate': 0.05605692298358814}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:03:18,269] Trial 42 finished with value: -0.5199508733384931 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 320, 'max_depth': 14, 'learning_rate': 0.05520236192668331}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:04:00,535] Trial 43 finished with value: -0.5196973216100779 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 431, 'max_depth': 13, 'learning_rate': 0.035706467913746584}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:04:24,066] Trial 44 finished with value: -0.518876002255629 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 317, 'max_depth': 10, 'learning_rate': 0.07641192082427112}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:04:50,657] Trial 45 finished with value: -0.5221670791141086 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 301, 'max_depth': 10, 'learning_rate': 0.07903765391073525}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:05:17,520] Trial 46 finished with value: -0.518886315549103 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 163, 'max_depth': 7, 'learning_rate': 0.07007868356190396}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:06:04,315] Trial 47 finished with value: -0.5212252515107818 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 228, 'max_depth': 11, 'learning_rate': 0.027398670727434394}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:06:10,162] Trial 48 finished with value: -0.6115839481993439 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 22, 'max_depth': 5, 'learning_rate': 0.06007012750447323}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:07:34,242] Trial 49 finished with value: -0.5209519324980904 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 456, 'max_depth': 8, 'learning_rate': 0.015447484226342003}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:07:57,264] Trial 50 finished with value: -0.5194832049863517 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 130, 'max_depth': 10, 'learning_rate': 0.09731868903508022}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:08:14,874] Trial 51 finished with value: -0.5233347162289249 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 88, 'max_depth': 7, 'learning_rate': 0.06645107455139054}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:08:51,443] Trial 52 finished with value: -0.6360634140637184 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 153, 'max_depth': 7, 'learning_rate': 0.006520527752318727}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:09:21,502] Trial 53 finished with value: -0.5226916400301639 and parameters: {'ensemble_model': 'HistGradientBoost', 'n_estimators': 182, 'max_depth': 6, 'learning_rate': 0.044612511984276584}. Best is trial 41 with value: -0.5170923246353741.
# [I 2025-03-25 10:11:17,038] Trial 54 finished with value: -0.5160309163485415 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 231, 'max_depth': 6, 'learning_rate': 0.07287735432570994}. Best is trial 54 with value: -0.5160309163485415.
# [I 2025-03-25 10:13:19,840] Trial 55 finished with value: -0.5185957191158622 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 298, 'max_depth': 5, 'learning_rate': 0.07467813959728022}. Best is trial 54 with value: -0.5160309163485415.
# [I 2025-03-25 10:15:30,184] Trial 56 finished with value: -0.518639797669538 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 257, 'max_depth': 6, 'learning_rate': 0.030483002671248878}. Best is trial 54 with value: -0.5160309163485415.
# [I 2025-03-25 10:17:34,342] Trial 57 finished with value: -0.5203571839580744 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 244, 'max_depth': 6, 'learning_rate': 0.029323541017522943}. Best is trial 54 with value: -0.5160309163485415.
# [I 2025-03-25 10:20:42,720] Trial 58 finished with value: -0.5205383805350076 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 293, 'max_depth': 5, 'learning_rate': 0.09880081100253015}. Best is trial 54 with value: -0.5160309163485415.
# [I 2025-03-25 10:23:35,817] Trial 59 finished with value: -0.5158485960339884 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 203, 'max_depth': 6, 'learning_rate': 0.05844932188959108}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 10:25:25,497] Trial 60 finished with value: -0.5193786478817893 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 92, 'max_depth': 8, 'learning_rate': 0.057174342726251076}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:08:47,199] Trial 61 finished with value: -0.5170081587550552 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 208, 'max_depth': 6, 'learning_rate': 0.07010942881611369}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:11:26,887] Trial 62 finished with value: -0.5174936936580039 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 222, 'max_depth': 6, 'learning_rate': 0.06955937630472277}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:13:19,467] Trial 63 finished with value: -0.6291921124806713 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 203, 'max_depth': 6, 'learning_rate': 0.004914313228433296}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:15:13,467] Trial 64 finished with value: -0.5165171830527684 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 225, 'max_depth': 6, 'learning_rate': 0.051107959229182695}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:16:19,582] Trial 65 finished with value: -0.5196296174873778 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 129, 'max_depth': 6, 'learning_rate': 0.058355245490043825}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:17:59,204] Trial 66 finished with value: -0.5198986267985245 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 168, 'max_depth': 7, 'learning_rate': 0.08048878428392021}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:19:30,506] Trial 67 finished with value: -0.5183651949049973 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 218, 'max_depth': 5, 'learning_rate': 0.06778144176347844}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:26:52,387] Trial 68 finished with value: -0.7628341218717242 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 235, 'max_depth': 26, 'learning_rate': 0.05234267840009978}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:32:51,502] Trial 69 finished with value: -0.7838907043972627 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 196, 'max_depth': 28, 'learning_rate': 0.03884960292491619}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:34:20,255] Trial 70 finished with value: -0.52429205741334 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 107, 'max_depth': 9, 'learning_rate': 0.0471670417767914}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:43:37,044] Trial 71 finished with value: -0.8013359858966518 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 284, 'max_depth': 32, 'learning_rate': 0.0394926535036106}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:46:56,175] Trial 72 finished with value: -0.5886799696632852 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 177, 'max_depth': 13, 'learning_rate': 0.06365562248313772}. Best is trial 59 with value: -0.5158485960339884.
# [I 2025-03-25 11:49:10,668] Trial 73 finished with value: -0.5156532504794074 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 268, 'max_depth': 6, 'learning_rate': 0.0465703966438768}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 11:50:56,803] Trial 74 finished with value: -0.5180403095242728 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 210, 'max_depth': 6, 'learning_rate': 0.08233212839304542}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 11:53:11,645] Trial 75 finished with value: -0.519495907122531 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 268, 'max_depth': 6, 'learning_rate': 0.08779510396191555}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 11:54:52,259] Trial 76 finished with value: -0.518683900209192 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 145, 'max_depth': 8, 'learning_rate': 0.05108513166210748}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 11:57:09,789] Trial 77 finished with value: -0.525120791060172 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 232, 'max_depth': 7, 'learning_rate': 0.08416646166257064}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 11:59:57,968] Trial 78 finished with value: -0.5187500255860953 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 332, 'max_depth': 6, 'learning_rate': 0.06779386513952086}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:01:31,142] Trial 79 finished with value: -0.5475787292561037 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 212, 'max_depth': 5, 'learning_rate': 0.015407462389531454}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:01:59,772] Trial 80 finished with value: -0.5396061301749814 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 43, 'max_depth': 7, 'learning_rate': 0.050929184952933}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:07:28,506] Trial 81 finished with value: -0.6979568756094752 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 200, 'max_depth': 20, 'learning_rate': 0.06059049240019464}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:12:34,649] Trial 82 finished with value: -0.744605017747641 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 167, 'max_depth': 24, 'learning_rate': 0.07714024154766838}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:14:45,698] Trial 83 finished with value: -0.5182494364734174 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 252, 'max_depth': 6, 'learning_rate': 0.03368081830550242}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:18:19,352] Trial 84 finished with value: -0.5282845034012018 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 278, 'max_depth': 9, 'learning_rate': 0.03998960080429321}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:21:43,484] Trial 85 finished with value: -0.5522850451451097 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 187, 'max_depth': 12, 'learning_rate': 0.025340073765387015}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:24:00,063] Trial 86 finished with value: -0.5178272421601642 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 227, 'max_depth': 7, 'learning_rate': 0.045460699774487266}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:28:20,052] Trial 87 finished with value: -0.579428677734182 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 347, 'max_depth': 8, 'learning_rate': 0.003482261756102262}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:30:36,863] Trial 88 finished with value: -0.5263994065643143 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 232, 'max_depth': 7, 'learning_rate': 0.08797170830265255}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:39:29,227] Trial 89 finished with value: -0.6497475786511286 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 422, 'max_depth': 15, 'learning_rate': 0.0701276084887711}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:40:30,282] Trial 90 finished with value: -0.5235670314089101 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 117, 'max_depth': 6, 'learning_rate': 0.04737733433245718}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:41:59,707] Trial 91 finished with value: -0.5209580491760183 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 212, 'max_depth': 5, 'learning_rate': 0.05578470169934506}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:44:03,532] Trial 92 finished with value: -0.5171888872054863 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 245, 'max_depth': 6, 'learning_rate': 0.04335490077865373}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:46:12,730] Trial 93 finished with value: -0.5169583189566812 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 255, 'max_depth': 6, 'learning_rate': 0.04478836815976645}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:48:55,319] Trial 94 finished with value: -0.5166431717083787 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 272, 'max_depth': 7, 'learning_rate': 0.033918756888403706}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:51:29,608] Trial 95 finished with value: -0.5161615295530655 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 306, 'max_depth': 6, 'learning_rate': 0.03712296986539323}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 12:58:44,229] Trial 96 finished with value: -0.6373938037485442 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 315, 'max_depth': 16, 'learning_rate': 0.03242123347795507}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 13:00:41,166] Trial 97 finished with value: -0.5332108572119519 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 267, 'max_depth': 5, 'learning_rate': 0.020405852848113477}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 13:08:50,739] Trial 98 finished with value: -0.5842253534250711 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 480, 'max_depth': 12, 'learning_rate': 0.03664887073154178}. Best is trial 73 with value: -0.5156532504794074.
# [I 2025-03-25 13:11:24,809] Trial 99 finished with value: -0.5189820364085048 and parameters: {'ensemble_model': 'GradientBoost', 'n_estimators': 293, 'max_depth': 6, 'learning_rate': 0.027747861441796744}. Best is trial 73 with value: -0.5156532504794074.
# FrozenTrial(number=73, state=1, values=[-0.5156532504794074], datetime_start=datetime.datetime(2025, 3, 25, 11, 46, 56, 176827), datetime_complete=datetime.datetime(2025, 3, 25, 11, 49, 10, 667713), params={'ensemble_model': 'GradientBoost', 'n_estimators': 268, 'max_depth': 6, 'learning_rate': 0.0465703966438768}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'ensemble_model': CategoricalDistribution(choices=('GradientBoost', 'RandomForest', 'HistGradientBoost')), 'n_estimators': IntDistribution(high=500, log=True, low=10, step=1), 'max_depth': IntDistribution(high=32, log=True, low=5, step=1), 'learning_rate': FloatDistribution(high=0.1, log=True, low=0.001, step=None)}, trial_id=73, value=None)

# %%
study.best_trial.params
# Out:
# {'ensemble_model': 'GradientBoost',
#  'n_estimators': 268,
#  'max_depth': 6,
#  'learning_rate': 0.0465703966438768}

# %%
final_model = GradientBoostingRegressor(n_estimators=268, max_depth=6, learning_rate=0.0465703966438768)
final_model.fit(X_filtered, y_filtered.flatten())
# Out:
# GradientBoostingRegressor(learning_rate=0.0465703966438768, max_depth=6,
#                           n_estimators=268)

# %%
y_hat_scaled = final_model.predict(X_test_filtered)

# %%
y_hat = preprocessor.inverse_transform(y_hat_scaled.reshape(-1,1))
# Out:
# /Users/mmartin/opt/anaconda3/envs/modelizacion_datos/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but QuantileTransformer was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import ( root_mean_squared_error, 
                             mean_absolute_error, 
                             mean_absolute_percentage_error )

# %%
y_true = y_test.values
y_pred = y_hat
rmse = root_mean_squared_error(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred)

# Format metrics with units and percentages
metrics = {
    "RMSE (₹)": f"{rmse:,.2f}",
    "MAE (₹)": f"{mae:,.2f}",
    "MAPE (%)": f"{mape:.2%}"
}

# Display metrics in a formatted table
print("\nModel Performance Metrics:\n")
print(f"{'Metric':<15} {'Value':>15}")
print("-" * 30)
for metric, value in metrics.items():
    print(f"{metric:<15} {value:>15}")

# Add a summary interpretation
print("\nInterpretation:")
print(f"- RMSE: The model's predictions are typically off by ₹{rmse:,.2f} on average")
print(f"- MAE: The average absolute error is ₹{mae:,.2f}")
print(f"- MAPE: The predictions are off by {mape:.1%} on average")
# Out:
# Model Performance Metrics:
#
# Metric                    Value
# ------------------------------
# RMSE (₹)          26,233,075.94
# MAE (₹)            6,268,114.94
# MAPE (%)                 41.15%
#
# Interpretation:
# - RMSE: The model's predictions are typically off by ₹26,233,075.94 on average
# - MAE: The average absolute error is ₹6,268,114.94
# - MAPE: The predictions are off by 41.2% on average
